# %%
import json

# %%
test = json.dumps({
    "temp": 1,
    "wet": 2
})

# %%
print(type(test))
print(test)
print(type(json.loads(test)))
print(json.loads(test))
test_dec = json.loads(test)
# Out:
# <class 'str'>
# {"temp": 1, "wet": 2}
# <class 'dict'>
# {'temp': 1, 'wet': 2}

# %%
test_dec["temp"]
# Out:
# 1
