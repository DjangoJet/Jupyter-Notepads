# %%
import numpy as np

# %% [markdown]
# # Zadanie 1

# %%
n = int(input())
# Out:
# 25

# %%
zad_1 = []
for i in range(n):
  if(i**2 + i**2 == n):
    zad_1.append(i)
print(zad_1)
# Out:
# []

# %%
m = int(input())
# Out:
# 2

# %%
zad_1_2 = []
for i in range(n):
  for j in range(n):
    if(i**m + j**m == n):
      zad_1_2.append([i,j])
print(zad_1_2)
# Out:
# [[0, 5], [3, 4], [4, 3], [5, 0]]

# %% [markdown]
# # Zadanie 2
#
# Nie jest jednoznaczne nie czaje o co chodzi typiarze/typowi

# %% [markdown]
# # Zadanie 3
# Warunek na ruszenie (tarcie statyczne)
# $$
# tan(\alpha) <= f_s \\
# $$
# Obliczanie przyspieszenia na równi
# $$
# a = g(sin(\alpha) - f_kcos(\alpha)) \\
# $$
# Równanie ruchu przyspieszonego
# $$
# s(t) = s_0 + v_0t + \frac{1}{2}at^2 \\
# $$

# %%
t = 10
angle = 30 # w stopniach
mass = 1 # masa nie ma znaczenia (podobnie jak z tym co spadnie pierwsze na ksiezycu mlotek czy piorko)
f_stat = 0 # statyczna
f_kine = 0 # kinetyczna
g = 9.81

# %%
if(np.tan(angle * np.pi/180) <= f_stat):
  print("ciało nie może ruszyć")
else:
  a = g*(np.sin(angle*np.pi/180) - f_kine*np.cos(angle*np.pi/180)) # trzeba pozamieniac na radiany dlatego te np.pi/180
  s = 0.5*a*t**2 # przy zalozeniu ze cialo ma polozenie i predkosc poczatkowa rowna 0
  print(s)
# Out:
# 245.24999999999997

# %% [markdown]
# Jak cos to moge tez dorobic zewnetrzna sile
